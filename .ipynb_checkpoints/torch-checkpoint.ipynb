# %%
# Build a simple GNN model (pyTorch)
path = "C:/Users/owena/Documents/AML_GNN"

# Install pytorch & matplotlib
# !pip install torch matplotlib
# Out:
# Requirement already satisfied: torch in C:\Users\owena\AppData\Local\Programs\Python\Python314\Lib\site-packages (2.13.0)
# Requirement already satisfied: matplotlib in C:\Users\owena\AppData\Local\Programs\Python\Python314\Lib\site-packages (3.11.0)
# Requirement already satisfied: filelock in C:\Users\owena\AppData\Local\Programs\Python\Python314\Lib\site-packages (from torch) (3.29.7)
# Requirement already satisfied: typing-extensions>=4.10.0 in C:\Users\owena\AppData\Local\Programs\Python\Python314\Lib\site-packages (from torch) (4.16.0)
# Requirement already satisfied: setuptools>=77.0.3 in C:\Users\owena\AppData\Local\Programs\Python\Python314\Lib\site-packages (from torch) (83.0.0)
# Requirement already satisfied: sympy>=1.13.3 in C:\Users\owena\AppData\Local\Programs\Python\Python314\Lib\site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in C:\Users\owena\AppData\Local\Programs\Python\Python314\Lib\site-packages (from torch) (3.6.1)
# Requirement already satisfied: jinja2 in C:\Users\owena\AppData\Local\Programs\Python\Python314\Lib\site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in C:\Users\owena\AppData\Local\Programs\Python\Python314\Lib\site-packages (from torch) (2026.6.0)
# Requirement already satisfied: contourpy>=1.0.1 in C:\Users\owena\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in C:\Users\owena\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in C:\Users\owena\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in C:\Users\owena\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: numpy>=1.25 in C:\Users\owena\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib) (2.5.1)
# Requirement already satisfied: packaging>=20.0 in C:\Users\owena\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib) (26.2)
# Requirement already satisfied: pillow>=9 in C:\Users\owena\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib) (12.3.0)
# Requirement already satisfied: pyparsing>=3 in C:\Users\owena\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in C:\Users\owena\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in C:\Users\owena\AppData\Local\Programs\Python\Python314\Lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in C:\Users\owena\AppData\Local\Programs\Python\Python314\Lib\site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in C:\Users\owena\AppData\Local\Programs\Python\Python314\Lib\site-packages (from jinja2->torch) (3.0.3)

# %%
import torch
import matplotlib.pyplot as plt

X = torch.tensor([
    [0.9],
    [0.10],
    [0.05]
])

# Create a label - "Bad guy - LimFW" 1, Good guy = "Owen 0"
A = torch.tensor([
    1,
    1,
    0
])

# Create the transaction network
A = torch.tensor([
    [0,1,0],
    [0,0,1],
    [0,0,0]
], dtype = torch.float)

I = torch.eye(3) # Create Identity Matrix
A_hat = A + I

print(A_hat)

# Normalise it
degree = A_hat.sum(dim = 1)
D = torch.diag(degree** - 0.5)
A_norm = D@A_hat@D

# Manually create the weights - actual (random)
w = torch.tensor([
    [0.5, 0.6]
])
H = A_norm@X
# Out:
# tensor([[1., 1., 0.],
#         [0., 1., 1.],
#         [0., 0., 1.]])
